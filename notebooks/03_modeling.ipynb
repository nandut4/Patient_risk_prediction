# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\Gouthami\Documents\DSML\Patient_risk_prediction\data\diabetes_prediction_dataset_processed.csv')

# %%
x_data = data.drop('diabetes', axis=1)

# %%
y_data = data['diabetes']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
model_LR = LogisticRegression()
model_LR.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_LR = model_LR.predict(X_test_scaled)

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, y_pred_LR))
print(classification_report(y_test, y_pred_LR))
# Out:
# [[18065   157]
#  [  654  1121]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     18222
#            1       0.88      0.63      0.73      1775
#
#     accuracy                           0.96     19997
#    macro avg       0.92      0.81      0.86     19997
# weighted avg       0.96      0.96      0.96     19997

# %%
# %pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\Users\Gouthami\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\Users\Gouthami\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (2.4.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\Users\Gouthami\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (1.17.1)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\Users\Gouthami\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (1.8.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in c:\Users\Gouthami\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\Users\Gouthami\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\Users\Gouthami\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)

# %%
print(y_train.value_counts())
print(y_train_smote.value_counts())
# Out:
# diabetes
# 0    73260
# 1     6725
# Name: count, dtype: int64
# diabetes
# 0    73260
# 1    73260
# Name: count, dtype: int64

# %%
model_LR.fit(X_train_smote, y_train_smote)
y_pred_smote = model_LR.predict(X_test_scaled)

# %%
print(confusion_matrix(y_test, y_pred_smote))
print(classification_report(y_test, y_pred_smote))
# Out:
# [[16212  2010]
#  [  198  1577]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94     18222
#            1       0.44      0.89      0.59      1775
#
#     accuracy                           0.89     19997
#    macro avg       0.71      0.89      0.76     19997
# weighted avg       0.94      0.89      0.91     19997

# %%
from sklearn.tree import DecisionTreeClassifier
model_DT = DecisionTreeClassifier(random_state=42)
model_DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_DT = model_DT.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred_DT))
print(classification_report(y_test, y_pred_DT))
# Out:
# [[17698   524]
#  [  460  1315]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     18222
#            1       0.72      0.74      0.73      1775
#
#     accuracy                           0.95     19997
#    macro avg       0.84      0.86      0.85     19997
# weighted avg       0.95      0.95      0.95     19997

# %%
y_pred_DT_train = model_DT.predict(X_train)
print(confusion_matrix(y_train, y_pred_DT_train))
print(classification_report(y_train, y_pred_DT_train))
# Out:
# [[73260     0]
#  [    0  6725]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     73260
#            1       1.00      1.00      1.00      6725
#
#     accuracy                           1.00     79985
#    macro avg       1.00      1.00      1.00     79985
# weighted avg       1.00      1.00      1.00     79985

# %%
from sklearn.ensemble import RandomForestClassifier
model_RF = RandomForestClassifier(n_estimators=100, random_state=42)
model_RF.fit(X_train, y_train)
y_pred_RF = model_RF.predict(X_test)
print(confusion_matrix(y_test, y_pred_RF))
print(classification_report(y_test, y_pred_RF))
# Out:
# [[18192    30]
#  [  565  1210]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     18222
#            1       0.98      0.68      0.80      1775
#
#     accuracy                           0.97     19997
#    macro avg       0.97      0.84      0.89     19997
# weighted avg       0.97      0.97      0.97     19997

# %%
y_pred_RF_train = model_RF.predict(X_train)
print(confusion_matrix(y_train, y_pred_RF_train))
print(classification_report(y_train, y_pred_RF_train))
# Out:
# [[73260     0]
#  [    2  6723]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     73260
#            1       1.00      1.00      1.00      6725
#
#     accuracy                           1.00     79985
#    macro avg       1.00      1.00      1.00     79985
# weighted avg       1.00      1.00      1.00     79985

# %%
#hyperparameter tuning
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='f1',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)

print(grid_search.best_params_)

best_rf = grid_search.best_estimator_
# Out:
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}

# %%
y_pred_best_RF = best_rf.predict(X_test)
print(confusion_matrix(y_test, y_pred_best_RF))
print(classification_report(y_test, y_pred_best_RF))
# Out:
# [[18207    15]
#  [  568  1207]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     18222
#            1       0.99      0.68      0.81      1775
#
#     accuracy                           0.97     19997
#    macro avg       0.98      0.84      0.89     19997
# weighted avg       0.97      0.97      0.97     19997

# %%
feature_importance = pd.DataFrame({
    'Feature': x_data.columns,
    'Importance': best_rf.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

print(feature_importance)
# Out:
#                         Feature  Importance
# 6                   HbA1c_level    0.438092
# 7           blood_glucose_level    0.319522
# 5                           bmi    0.071970
# 2                           age    0.067462
# 0                    Unnamed: 0    0.058671
# 3                  hypertension    0.014119
# 4                 heart_disease    0.010266
# 1                        gender    0.005408
# 11        smoking_history_never    0.004371
# 10       smoking_history_former    0.003721
# 8       smoking_history_current    0.002561
# 12  smoking_history_not current    0.002083
# 9          smoking_history_ever    0.001755

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))

sns.barplot(
    data=feature_importance,
    x='Importance',
    y='Feature'
)

plt.title("Feature Importance - Random Forest")

plt.show()

# %%
from sklearn.metrics import roc_auc_score, roc_curve
y_prob = model_RF.predict_proba(X_test)[:,1]
auc_score = roc_auc_score(y_test, y_prob)
print("ROC-AUC Score:", auc_score)
# Out:
# ROC-AUC Score: 0.9657161827291265

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"AUC = {auc_score:.3f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
